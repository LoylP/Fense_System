# %% [markdown]
# ## Thử nghiệm khả năng nhận diện tin giả của các model LLMs

# %% [markdown]
# #### Khởi tạo

# %%
import sys
import os
import requests
import json

current_dir = os.getcwd()
project_root = os.path.abspath(os.path.join(current_dir, '..'))
sys.path.append(project_root)

# Bây giờ import
from CrewAI.tools.check import (
    check_url_virustotal, parse_vt_result_for_display,
    check_email_validity, parse_email_result,
    check_phone_validity, parse_phone_result
)

from CrewAI.tools.search_googleapi import search_google_api

# %%
API_URL = "http://172.17.128.1:1234/v1/chat/completions"
# MODEL_NAME = qwen2.5-7b-instruct-1m vicuna-7b-v1.5  phi-4 meta-llama-3.1-8b-instruct deepseek-r1-distill-llama-8b mistral-7b-v0.1
MODEL_NAME = "qwen2.5-7b-instruct-1m"

# %% [markdown]
# #### Lọc input đầu vào, trích xuất thông tin quan trọng

# %%
def extract_fields(data: dict):
    summary = data.get('summary', '').strip()
    keywords_list = data.get('keywords', [])
    request_user = data.get('request_user', '').strip()
    email = data.get('email', '').strip()
    phone = data.get('phone', '').strip()
    url = data.get('url', '').strip()

    keywords = ", ".join(str(k) for k in keywords_list if isinstance(k, str))

    return summary, keywords, request_user, email, phone, url

def llm_extract(input_text: str, api_url: str, model_name: str):
    messages = [
        {
            "role": "system",
            "content": (
                '''Bạn là trợ lý AI có nhiệm vụ trích xuất thông tin chính xác từ văn bản đầu vào.

                Yêu cầu:

                1. Tóm tắt (summary): Tóm tắt ngắn gọn, rõ ràng nội dung văn bản đầu vào.
                2. Keywords: Lấy ra danh sách các từ khóa quan trọng nhất phục vụ việc tìm kiếm thông tin trên Google.
                3. Emails, phones, urls: Chỉ trích xuất các email, số điện thoại, URL xuất hiện rõ ràng trong văn bản đầu vào. Nếu không tìm thấy, trả về danh sách rỗng.
                4. Tuyệt đối không đoán hay thêm thông tin không có trong văn bản đầu vào.

                Output trả về duy nhất là một chuỗi JSON có cấu trúc:

                {
                "summary": "...",
                "keywords": [...],
                "emails": [...],
                "phones": [...],
                "urls": [...]
                }

                Không kèm theo lời giải thích, không có code block, không thêm ký tự thừa.'''
            )
        },
        {
            "role": "user",
            "content": input_text
        }
    ]

    response = requests.post(
        api_url,
        headers={"Content-Type": "application/json"},
        json={
            "model": model_name,
            "messages": messages,
            "temperature": 0.7,
            "max_tokens": 1024,
            "stream": False
        }
    )

    if response.status_code != 200:
        raise RuntimeError(f"LLM request failed: {response.status_code} {response.text}")

    result = response.json()
    content = result['choices'][0]['message']['content']

    try:
        json_str = content.strip()
        if json_str.startswith("{") and "'" in json_str:
            json_str = json_str.replace("'", '"')
        parsed = json.loads(json_str)
    except json.JSONDecodeError:
        parsed = {}

    # Fallback nếu summary hoặc keywords rỗng
    summary = parsed.get("summary", "").strip()
    keywords = parsed.get("keywords", [])
    request_user = parsed.get("request_user", "")
    emails = parsed.get("emails", [])
    phones = parsed.get("phones", [])
    urls = parsed.get("urls", [])

    if not summary:
        summary = input_text
    if not keywords:
        keywords = list({w.lower() for w in input_text.split() if len(w) > 3})

    email = emails[0] if isinstance(emails, list) and len(emails) > 0 else ""
    phone = phones[0] if isinstance(phones, list) and len(phones) > 0 else ""
    url = urls[0] if isinstance(urls, list) and len(urls) > 0 else ""

    return {
        "summary": summary,
        "keywords": keywords,
        "request_user": request_user,
        "email": email,
        "phone": phone,
        "url": url
    }

# %% [markdown]
# #### Xác minh thông tin

# %%
def build_checks_summary(url=None, email=None, phone=None):
    parts = []

    if url:
        url_result = check_url_virustotal(url)
        check_url = parse_vt_result_for_display(url_result)
        parts.append(f"Kết quả kiểm tra URL: {check_url}")

    if email:
        mail_result = check_email_validity(email)
        check_mail = parse_email_result(mail_result)
        parts.append(f"Kết quả kiểm tra Mail: {check_mail}")

    if phone:
        phone_result = check_phone_validity(phone)
        check_phone = parse_phone_result(phone_result)
        parts.append(f"Kết quả kiểm tra Phone: {check_phone}")

    return "\n".join(parts)

def build_news_summary(keywords):
    news_df = search_google_api(keywords)

    lines = []
    for _, row in news_df.iterrows():
        title = row.get('title', '')
        content = row.get('content', '')
        lines.append(f"- Tiêu đề: {title}\n  Nội dung: {content[:300]}...")
    return "\n".join(lines)

def verify_scam(
    summary, url, email, phone, keywords, api_url, model_name):
    check_summary = build_checks_summary(url, email, phone)
    news_summary = build_news_summary(keywords)

    prompt_system = f"""
    Bạn là trợ lý AI chuyên xác minh tính xác thực của thông tin, giúp phân loại yêu cầu của người dùng có phải tin tức giả mạo, lừa đảo hay đáng nghi vấn không.

    Thông tin đầu vào gồm:

    1. Tóm tắt yêu cầu (summary):
    {summary}

    2. Kết quả kiểm tra URL, Email, Số điện thoại (nếu có):
    {check_summary}

    3. Các tin tức tham khảo liên quan được tìm thấy trên internet (có thể không hoàn toàn liên quan):
    {news_summary}

    Dựa vào các thông tin trên, vui lòng phân loại yêu cầu của người dùng thuộc loại nào trong ba nhóm sau:

    - ✅ real: thông tin tin cậy, không có dấu hiệu lừa đảo hay giả mạo
    - ❌ fake: thông tin có dấu hiệu giả mạo, lừa đảo

    Chỉ trả lời đúng theo định dạng sau, không thêm giải thích hay bình luận khác:

    Kết luận: <✅ real | ❌ fake>
    """

    messages = [
        {"role": "system", "content": prompt_system},
        {"role": "user", "content": ""}
    ]

    response = requests.post(
        api_url,
        headers={"Content-Type": "application/json"},
        json={
            "model": model_name,
            "messages": messages,
            "temperature": 0,
            "max_tokens": 20000,
            "stream": False
        }
    )

    if response.status_code != 200:
        raise RuntimeError(f"LLM request failed: {response.status_code} {response.text}")

    result = response.json()
    content = result['choices'][0]['message']['content'].strip()
    return content

# %% [markdown]
# #### Test Model with 1 input

# %%
input_text = 'Bannon thẳng_thừng chỉ_trích Trung_Quốc và các "" đồng_minh "" như Kissinger , Bill_Gates khiến truyền_thông Trung_Quốc "" gây_chiến "" với ông '

result = llm_extract(input_text, API_URL, MODEL_NAME)
print(result)

summary, keywords, request_user, email, phone, url = extract_fields(result)

print("Summary:", summary)
print("Keywords:", keywords)
print("Request User:", request_user)
print("Emails:", email)
print("Phones:", phone)
print("URLs:", url)
# Out:
# {'summary': 'Bannon thẳng_thừng chỉ_trích Trung_Quốc và các "" đồng_minh "" như Kissinger , Bill_Gates khiến truyền_thông Trung_Quốc "" gây_chiến "" với ông ', 'keywords': ['thẳng_thừng', 'bill_gates', 'kissinger', 'chỉ_trích', 'gây_chiến', 'khiến', 'bannon', 'truyền_thông', 'đồng_minh', 'trung_quốc'], 'request_user': '', 'email': '', 'phone': '', 'url': ''}
# Summary: Bannon thẳng_thừng chỉ_trích Trung_Quốc và các "" đồng_minh "" như Kissinger , Bill_Gates khiến truyền_thông Trung_Quốc "" gây_chiến "" với ông
# Keywords: thẳng_thừng, bill_gates, kissinger, chỉ_trích, gây_chiến, khiến, bannon, truyền_thông, đồng_minh, trung_quốc
# Request User:
# Emails:
# Phones:
# URLs:

# %%
output = verify_scam(summary, url, email, phone, keywords, API_URL, MODEL_NAME)

print(output)
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 output = verify_scam(summary, url, email, phone, keywords, API_URL, MODEL_NAME)
#       3 print(output)
#
# Cell In[4], line 34, in verify_scam(summary, url, email, phone, keywords, api_url, model_name)
#      31 def verify_scam(
#      32     summary, url, email, phone, keywords, api_url, model_name):
#      33     check_summary = build_checks_summary(url, email, phone)
# ---> 34     news_summary = build_news_summary(keywords)
#      36     prompt_system = f"""
#      37     Bạn là trợ lý AI chuyên xác minh tính xác thực của thông tin, giúp phân loại yêu cầu của người dùng có phải tin tức giả mạo, lừa đảo hay đáng nghi vấn không.
#      38
#    (...)     57     Kết luận: <✅ real | ❌ fake>
#      58     """
#      60     messages = [
#      61         {"role": "system", "content": prompt_system},
#      62         {"role": "user", "content": ""}
#      63     ]
#
# Cell In[4], line 22, in build_news_summary(keywords)
#      21 def build_news_summary(keywords):
# ---> 22     news_df = search_google_api(keywords)
#      24     lines = []
#      25     for _, row in news_df.iterrows():
#
# File ~/Fense_System/CrewAI/tools/search_googleapi.py:36, in search_google_api(query, max_results)
#      33 if not api_key or not cse_id:
#      34     raise ValueError("🔑 API key hoặc Search Engine ID bị thiếu trong môi trường")
# ---> 36 search_results = google_search(query, api_key, cse_id, num=10)
#      38 results = []
#      39 with ThreadPoolExecutor(max_workers=5) as executor:
#
# File ~/Fense_System/CrewAI/tools/search_googleapi.py:13, in google_search(query, api_key, cse_id, num)
#      11 def google_search(query, api_key, cse_id, num=10):
#      12     service = build("customsearch", "v1", developerKey=api_key)
# ---> 13     res = service.cse().list(q=query, cx=cse_id, num=num).execute()
#      14     return res.get('items', [])
#
# File ~/Fense_System/env/lib/python3.12/site-packages/googleapiclient/_helpers.py:130, in positional.<locals>.positional_decorator.<locals>.positional_wrapper(*args, **kwargs)
#     128     elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129         logger.warning(message)
# --> 130 return wrapped(*args, **kwargs)
#
# File ~/Fense_System/env/lib/python3.12/site-packages/googleapiclient/http.py:938, in HttpRequest.execute(self, http, num_retries)
#     936     callback(resp)
#     937 if resp.status >= 300:
# --> 938     raise HttpError(resp, content, uri=self.uri)
#     939 return self.postproc(resp, content)
#
# HttpError: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=th%E1%BA%B3ng_th%E1%BB%ABng%2C+bill_gates%2C+kissinger%2C+ch%E1%BB%89_tr%C3%ADch%2C+g%C3%A2y_chi%E1%BA%BFn%2C+khi%E1%BA%BFn%2C+bannon%2C+truy%E1%BB%81n_th%C3%B4ng%2C+%C4%91%E1%BB%93ng_minh%2C+trung_qu%E1%BB%91c&cx=a59483bd7e3a449a9&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">

# %% [markdown]
# ## Test model with test_dataset

# %%
import pandas as pd

df = pd.read_csv('/mnt/c/Users/trieuph5/Documents/FTI/KL/test.csv')
df_subset = df.copy() #df.head(100).copy()
llm_outputs = []

for i, row in df_subset.iterrows():
    input_text = row['text']
    
    try:
        result = llm_extract(input_text, API_URL, MODEL_NAME)
        summary, keywords, request_user, email, phone, url = extract_fields(result)
        output = verify_scam(summary, url, email, phone, keywords, API_URL, MODEL_NAME)

    except Exception as e:
        output = f"Error: {str(e)}"
    
    llm_outputs.append(output)
    print(output)

df_subset['qwen2.5'] = llm_outputs
df.loc[df_subset.index, 'qwen2.5'] = df_subset['qwen2.5']
df.to_csv('test_output_qwen2.5.csv', index=False)

print("Xử lý xong")
# Out:
# Kết luận: <❌ fake>
# Kết luận: ❌ fake
# Kết luận: ❌ fake
# ⚠️ Lỗi xử lý URL: https://vietteltelecom.vn/tin-tuc/chi-tiet/huong-dan-khach-hang-cach-doi-diem-viettel-nhan-uu-dai-data-hap-dan-tren-my-viettel/13314920 | 'NoneType' object has no attribute 'strip'
# Kết luận: ❌ fake
# Kết luận: ❌ fake
# Kết luận: ❌ fake
# Kết luận: ✅ real
# Kết luận: ❌ fake
# Kết luận: ✅ real
# Kết luận: ❌ fake
# Kết luận: ❌ fake
# Kết luận: ❌ fake
# Kết luận: ❌ fake
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ❌ fake
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# ⚠️ Lỗi xử lý URL: https://vnu.edu.vn/ttsk/?C1636/N36769/Khoi-day-tu-duy-sang-tao-va-su-ho-tro-cua-AI-trong-hoc-tap.htm | 'NoneType' object has no attribute 'strip'
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ❌ fake
# Kết luận: ❌ fake
# Kết luận: ❌ fake
# Kết luận: ✅ real
# Kết luận: ❌ fake
# Kết luận: ✅ real
# Kết luận: ❌ fake
# Kết luận: ❌ fake
# Kết luận: ❌ fake
# Kết luận: ❌ fake
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ❌ fake
# Kết luận: ❌ fake
# Kết luận: ❌ fake
# Kết luận: ✅ real
# Kết luận: ❌ fake
# Kết luận: ❌ fake
# Kết luận: ❌ fake
# Kết luận: ✅ real
# Kết luận: ❌ fake
# Kết luận: ❌ fake
# Kết luận: ❌ fake
# Kết luận: ❌ fake
# Kết luận: ❌ fake
# Kết luận: ❌ fake
# Kết luận: ❌ fake
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: ❌ fake
# Kết luận: ❌ fake
# Kết luận: ❌ fake
# Kết luận: ✅ real
# Kết luận: <✅ real>
# Kết luận: ✅ real
# Kết luận: ✅ real
# Kết luận: <❌ fake>
# Kết luận: <❌ fake>
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=M%E1%BB%99t+nh%C3%B3m+chuy%C3%AAn+gia+b%E1%BA%A5t+bi%E1%BA%BFt+t%C3%AAn+%C4%91%C3%A3+%C4%91%C6%B0a+ra+quan+%C4%91i%E1%BB%83m+cho+r%E1%BA%B1ng+vi%E1%BB%87c+s%E1%BB%AD+d%E1%BB%A5ng+m%E1%BA%A1ng+5G+c%C3%B3+th%E1%BB%83+d%E1%BA%ABn+%C4%91%E1%BA%BFn+nguy+c%C6%A1+cao+h%C6%A1n+m%E1%BA%AFc+ung+th%C6%B0.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=L%C3%A3nh+%C4%91%E1%BA%A1o+t%E1%BB%AB+M%E1%BB%B9+v%C3%A0+Trung+Qu%E1%BB%91c+%C4%91%C3%A3+g%E1%BA%B7p+g%E1%BB%A1+%C4%91%E1%BB%83+th%E1%BA%A3o+lu%E1%BA%ADn+v%E1%BB%81+vi%E1%BB%87c+gi%E1%BA%A3i+quy%E1%BA%BFt+v%E1%BA%A5n+%C4%91%E1%BB%81+bi%E1%BA%BFn+%C4%91%E1%BB%95i+kh%C3%AD+h%E1%BA%ADu.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Th%C3%B4ng+tin+n%C3%A0y+l%C3%A0+m%E1%BB%99t+tuy%C3%AAn+b%E1%BB%91+gi%E1%BA%A3+%C4%91%E1%BB%8Bnh+m%C3%A0+ch%C6%B0a+c%C3%B3+b%E1%BA%B1ng+ch%E1%BB%A9ng+khoa+h%E1%BB%8Dc+n%C3%A0o+%C4%91%E1%BB%83+x%C3%A1c+nh%E1%BA%ADn.+Vi%E1%BB%87c+bi%E1%BA%BFn+%C4%91%E1%BB%95i+kh%C3%AD+h%E1%BA%ADu+t%C3%A1c+%C4%91%E1%BB%99ng+%C4%91%E1%BA%BFn+c%C3%A1c+khu+v%E1%BB%B1c+kh%C3%A1c+nhau+tr%C3%AAn+th%E1%BA%BF+gi%E1%BB%9Bi+ph%E1%BB%A5+thu%E1%BB%99c+v%C3%A0o+nhi%E1%BB%81u+y%E1%BA%BFu+t%E1%BB%91+nh%C6%B0+v%E1%BB%8B+tr%C3%AD+%C4%91%E1%BB%8Ba+l%C3%BD%2C+ch%C3%ADnh+s%C3%A1ch+b%E1%BA%A3o+v%E1%BB%87+m%C3%B4i+tr%C6%B0%E1%BB%9Dng+v%C3%A0+kh%E1%BA%A3+n%C4%83ng+th%C3%ADch+%E1%BB%A9ng+c%E1%BB%A7a+m%E1%BB%97i+qu%E1%BB%91c+gia.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=C%C3%A1c+b%C3%A1c+s%C4%A9+khuy%C3%AAn+n%C3%AAn+t%E1%BA%ADp+th%E1%BB%83+d%E1%BB%A5c+h%C3%A0ng+ng%C3%A0y+%C4%91%E1%BB%83+n%C3%A2ng+cao+s%E1%BB%A9c+kh%E1%BB%8Fe+tim+m%E1%BA%A1ch+v%C3%A0+gi%E1%BA%A3m+kh%E1%BA%A3+n%C4%83ng+m%E1%BA%AFc+b%E1%BB%87nh+m%C3%A3n+t%C3%ADnh.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=V%C3%A0o+ng%C3%A0y+18+th%C3%A1ng+5%2C+b%C3%A1o+VNExpress+%C4%91%C3%A3+%C4%91%C6%B0a+tin+v%E1%BB%81+xu+h%C6%B0%E1%BB%9Bng+c%C3%A1c+doanh+nghi%E1%BB%87p+kh%E1%BB%9Fi+nghi%E1%BB%87p+trong+l%C4%A9nh+v%E1%BB%B1c+c%C3%B4ng+ngh%E1%BB%87+%E1%BB%9F+Vi%E1%BB%87t+Nam+hi%E1%BB%87n+%C4%91ang+nh%E1%BA%ADn+%C4%91%C6%B0%E1%BB%A3c+s%E1%BB%B1+quan+t%C3%A2m+v%C3%A0+%C4%91%E1%BA%A7u+t%C6%B0+l%E1%BB%9Bn+t%E1%BB%AB+c%C3%A1c+nh%C3%A0+%C4%91%E1%BA%A7u+t%C6%B0.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Facebook+cho+bi%E1%BA%BFt+ng%C6%B0%E1%BB%9Di+d%C3%B9ng+s%E1%BA%BD+%C4%91%C6%B0%E1%BB%A3c+nh%E1%BA%ADn+ti%E1%BB%81n+khi+nh%E1%BA%A5n+like+v%C3%A0o+b%C3%A0i+vi%E1%BA%BFt+t%E1%BB%AB+c%C3%A1c+doanh+nghi%E1%BB%87p+l%E1%BB%9Bn.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Nghi%C3%AAn+c%E1%BB%A9u+cho+bi%E1%BA%BFt+u%E1%BB%91ng+5+t%C3%A1ch+c%C3%A0+ph%C3%AA+m%E1%BB%97i+ng%C3%A0y+c%C3%B3+th%E1%BB%83+gi%C3%BAp+t%C4%83ng+tu%E1%BB%95i+th%E1%BB%8D+l%C3%AAn+%C4%91%E1%BA%BFn+150+tu%E1%BB%95i.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Ch%C3%ADnh+ph%E1%BB%A7+Vi%E1%BB%87t+Nam+ra+quy%E1%BA%BFt+%C4%91%E1%BB%8Bnh+x%C3%A2y+d%E1%BB%B1ng+th%C3%AAm+c%C3%A1c+b%E1%BB%87nh+vi%E1%BB%87n+chuy%C3%AAn+s%C3%A2u+%E1%BB%9F+c%C3%A1c+th%C3%A0nh+ph%E1%BB%91+l%E1%BB%9Bn.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%C4%90%E1%BA%A1i+h%E1%BB%8Dc+Harvard+cung+c%E1%BA%A5p+h%E1%BB%8Dc+b%E1%BB%95ng+mi%E1%BB%85n+ph%C3%AD+cho+b%E1%BA%A5t+k%E1%BB%B3+sinh+vi%C3%AAn+n%C3%A0o+t%E1%BB%AB+kh%E1%BA%AFp+n%C6%A1i+tr%C3%AAn+th%E1%BA%BF+gi%E1%BB%9Bi+m%C3%A0+kh%C3%B4ng+c%E1%BA%A7n+%C4%91%E1%BA%A1t+th%C3%A0nh+t%C3%ADch+GPA+c%E1%BB%A5+th%E1%BB%83.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=B%E1%BB%99+Gi%C3%A1o+d%E1%BB%A5c+v%C3%A0+%C4%90%C3%A0o+t%E1%BA%A1o+c%C3%B4ng+nh%E1%BA%ADn+h%E1%BB%87+th%E1%BB%91ng+gi%C3%A1o+d%E1%BB%A5c+tr%E1%BB%B1c+tuy%E1%BA%BFn+l%C3%A0+m%E1%BB%99t+xu+h%C6%B0%E1%BB%9Bng+ph%C3%A1t+tri%E1%BB%83n+b%E1%BB%81n+v%E1%BB%AFng+trong+gi%C3%A1o+d%E1%BB%A5c+%C4%91%E1%BA%A1i+h%E1%BB%8Dc.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Mini_World%2C+m%E1%BB%99t+tr%C3%B2+ch%C6%A1i+t%C6%B0%C6%A1ng+t%E1%BB%B1+nh%C6%B0+Minecraft+d%C3%A0nh+cho+tr%E1%BA%BB+em%2C+%C4%91%C3%A3+xu%E1%BA%A5t+hi%E1%BB%87n+v%C3%A0+tr%E1%BB%9F+th%C3%A0nh+ch%E1%BB%A7+%C4%91%E1%BB%81+th%E1%BA%A3o+lu%E1%BA%ADn+khi+c%C3%B3+nh%E1%BB%AFng+k%E1%BA%BB+g%E1%BB%ADi+tin+nh%E1%BA%AFn+d%E1%BB%A5+d%E1%BB%97%2C+k%C3%AAu+g%E1%BB%8Di+ng%C6%B0%E1%BB%9Di+ch%C6%A1i+g%E1%BB%ADi+%E1%BA%A3nh+khi%E1%BA%BFm+nh%C3%A3.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=D%E1%BB%B1+b%C3%A1o+th%E1%BB%9Di+ti%E1%BA%BFt+cho+ng%C3%A0y+28%2F3%2C+kh%C3%B4ng+kh%C3%AD+l%E1%BA%A1nh+s%E1%BA%BD+t%C3%A1c+%C4%91%E1%BB%99ng+%C4%91%E1%BA%BFn+khu+v%E1%BB%B1c+B%E1%BA%AFc+B%E1%BB%99+v%E1%BB%9Bi+hi%E1%BB%87n+t%C6%B0%E1%BB%A3ng+m%C6%B0a+r%C3%A0o+xu%E1%BA%A5t+hi%E1%BB%87n+t%E1%BA%A1i+H%C3%A0+N%E1%BB%99i.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=H%E1%BB%8Fi+v%E1%BB%81+vi%E1%BB%87c+FPT+Online+%C4%91%C3%A3+c%E1%BA%AFt+gi%E1%BA%A3m+42%2C5%25+chi+ph%C3%AD+nh%C3%A2n+c%C3%B4ng+v%C3%A0+li%E1%BB%87u+c%C3%B3+%C4%91%E1%BB%93ng+nghi%E1%BB%87p+c%E1%BB%A7a+Vnexpress%2C+Ngoisao+ho%E1%BA%B7c+Ione+n%C3%A0o+b%E1%BB%8B+%E1%BA%A3nh+h%C6%B0%E1%BB%9Fng.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=T%C3%B2a+%C3%A1n+%C4%91%C3%A3+tuy%C3%AAn+%C3%A1n+b%E1%BB%8B+c%C3%A1o+Nguy%E1%BB%85n+V%C4%83n+Hi%E1%BA%BFn%2C+t%E1%BB%ABng+l%C3%A0+T%C6%B0+l%E1%BB%87nh+Qu%C3%A2n+ch%E1%BB%A7ng+H%E1%BA%A3i+qu%C3%A2n%2C+ph%E1%BA%A3i+ng%E1%BB%93i+t%C3%B9+trong+v%C3%B2ng+4+n%C4%83m.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Ph%E1%BA%A3n_%E1%BB%A8ng+%22+C%E1%BB%B1c_K%E1%BB%B3+H%C3%A8n_H%E1%BA%A1+%22+c%E1%BB%A7a+ch%C3%ADnh_quy%E1%BB%81n+Trung_Qu%E1%BB%91c+Tr%C6%B0%E1%BB%9Bc+D%E1%BB%8Bch_Corona+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+_+C%C3%A1ch+x%E1%BB%AD_l%C3%BD+d%E1%BB%8Bch+Corona+c%E1%BB%A7a+Trung_Qu%E1%BB%91c+l%C3%A0+c%E1%BB%B1c_k%E1%BB%B3+h%C3%A8n_h%E1%BA%A1+.T%E1%BB%AB+che_%C4%91%E1%BA%ADy+l%C3%BAc+m%E1%BB%9Bi+c%C3%B3+d%E1%BB%8Bch+cho+t%E1%BB%9Bi+%C4%91%C3%A0n_%C3%A1p+quy_m%C3%B4+l%E1%BB%9Bn+.Qua+%C4%91%E1%BB%A3t+d%E1%BB%8Bch+n%C3%A0y+%2C+%C4%90%E1%BA%A3ng+C%E1%BB%99ng_s%E1%BA%A3n+Trung_Qu%E1%BB%91c+m%E1%BB%99t+l%E1%BA%A7n+n%E1%BB%AFa+cho+th%E1%BA%A5y+sinh_m%E1%BA%A1ng+ng%C6%B0%E1%BB%9Di_d%C3%A2n+kh%C3%B4ng+l%C3%A0+g%C3%AC+so+v%E1%BB%9Bi+quy%E1%BB%81n_l%E1%BB%B1c+cai_tr%E1%BB%8B+c%E1%BB%A7a+ch%E1%BA%BF_%C4%91%E1%BB%99+%C4%91%E1%BB%99c_t%C3%A0i+l%E1%BB%9Bn+nh%E1%BA%A5t+th%E1%BA%BF_gi%E1%BB%9Bi+.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=C%C3%A1c+chuy%C3%AAn+gia+khuy%E1%BA%BFn+ngh%E1%BB%8B+m%E1%BB%8Di+ng%C6%B0%E1%BB%9Di+c%E1%BA%A7n+s%E1%BB%91ng+v%C3%A0+l%C3%A0m+vi%E1%BB%87c+c%E1%BA%A9n+tr%E1%BB%8Dng+%C4%91%E1%BB%83+th%C3%ADch+nghi+v%E1%BB%9Bi+%C4%91%E1%BA%A1i+d%E1%BB%8Bch+COVID-19%2C+cho+%C4%91%E1%BA%BFn+khi+c%C3%B3+v%E1%BA%AFc-xin.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=C%E1%BB%A5c+Thu%E1%BA%BF+H%C3%A0+N%E1%BB%99i+%C4%91ang+th%E1%BB%B1c+hi%E1%BB%87n+c%C3%A1c+bi%E1%BB%87n+ph%C3%A1p+%C4%91%E1%BB%83+truy+thu+thu%E1%BA%BF+gi%C3%A1+tr%E1%BB%8B+gia+t%C4%83ng+v%C3%A0+thu%E1%BA%BF+thu+nh%E1%BA%ADp+c%C3%A1+nh%C3%A2n.%0A%0ATheo+quy+%C4%91%E1%BB%8Bnh%2C+doanh+thu+t%E1%BB%AB+100+tri%E1%BB%87u+%C4%91%E1%BB%93ng%2Fn%C4%83m+tr%E1%BB%9F+l%C3%AAn+l%C3%A0+ph%E1%BA%A3i+n%E1%BB%99p+thu%E1%BA%BF.+C%C3%A1c+c%C3%A1+nh%C3%A2n+nh%E1%BA%ADn+thu+nh%E1%BA%ADp+t%E1%BB%AB+Facebook%2C+Google%2C+Youtube...+%C4%91%C6%B0%E1%BB%A3c+x%E1%BA%BFp+l%C3%A0+c%C3%A1+nh%C3%A2n+kinh+doanh%2C+n%E1%BB%99p+thu%E1%BA%BF+theo+t%E1%BB%B7+l%E1%BB%87+5%25+gi%C3%A1+tr%E1%BB%8B+gia+t%C4%83ng+v%C3%A0+2%25+thu%E1%BA%BF+thu+nh%E1%BA%ADp+c%C3%A1+nh%C3%A2n.+C%E1%BB%A5c+Thu%E1%BA%BF+H%C3%A0+N%E1%BB%99i+hi%E1%BB%87n+%C4%91%C3%A3+x%C3%A1c+%C4%91%E1%BB%8Bnh+c%C3%B3+h%C6%A1n+1.100+c%C3%A1+nh%C3%A2n+ho%E1%BA%A1t+%C4%91%E1%BB%99ng+kinh+doanh+ph%E1%BA%A7n+m%E1%BB%81m%2C+d%E1%BB%8Bch+v%E1%BB%A5+%C4%91i%E1%BB%87n+t%E1%BB%AD%2C+tr%C3%B2+ch%C6%A1i+tr%C3%AAn+m%E1%BA%A1ng+-+c%C3%B3+t%E1%BB%95ng+thu+nh%E1%BA%ADp+trong+3+n%C4%83m+g%E1%BA%A7n+%C4%91%C3%A2y+%282%3CPHONE%3E%29+l%C3%A0+4.800+t%E1%BB%B7+%C4%91%E1%BB%93ng.+Trong+%C4%91%C3%B3%2C+c%C3%A1+nh%C3%A2n+c%C3%B3+thu+nh%E1%BA%ADp+cao+nh%E1%BA%A5t+l%C3%AAn+%C4%91%E1%BA%BFn+140+t%E1%BB%B7+%C4%91%E1%BB%93ng.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Qu%E1%BA%A3ng+Ninh+%C4%91%C3%A3+c%C3%B4ng+nh%E1%BA%ADn+r%E1%BA%B1ng+Vingroup+v%C3%A0+Vinhomes+c%C3%B3+%C4%91%E1%BB%A7+n%C4%83ng+l%E1%BB%B1c+%C4%91%E1%BB%83+tri%E1%BB%83n+khai+d%E1%BB%B1+%C3%A1n+h%E1%BA%A1+long+xanh+v%E1%BB%9Bi+quy+m%C3%B4+10+t%E1%BB%B7+USD.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=%C4%90%E1%BB%99i+ki%E1%BB%83m+tra+t%E1%BA%A1i+C%C3%A0+Mau+ph%C3%A1t+hi%E1%BB%87n+nhi%E1%BB%81u+tr%C6%B0%E1%BB%9Dng+h%E1%BB%A3p+c%C3%B3+th%C3%A1i+%C4%91%E1%BB%99+giao+ti%E1%BA%BFp+ch%C6%B0a+t%E1%BB%91t+v%E1%BB%9Bi+d%C3%A2n%2C+th%E1%BA%ADm+ch%C3%AD+c%C3%B3+tr%C6%B0%E1%BB%9Dng+h%E1%BB%A3p+nh%C5%A9ng+nhi%E1%BB%85u%2C+g%C3%A2y+phi%E1%BB%81n+h%C3%A0.+C%C3%A1c+m%E1%BB%A9c+x%E1%BB%AD+l%C3%BD+dao+%C4%91%E1%BB%99ng+t%E1%BB%AB+nh%E1%BA%AFc+nh%E1%BB%9F+cho+%C4%91%E1%BA%BFn+k%E1%BB%B7+lu%E1%BA%ADt+v%C3%A0+khai+tr%E1%BB%AB+%C4%90%E1%BA%A3ng.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Kết luận: ✅ real
# /home/trieuph5/Fense_System/env/lib/python3.12/site-packages/bs4/__init__.py:473: XMLParsedAsHTMLWarning: It looks like you're using an HTML parser to parse an XML document.
#
# Assuming this really is an XML document, what you're doing might work, but you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the Python package 'lxml' installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#
# If you want or need to use an HTML parser on this document, you can make this warning go away by filtering it. To do that, run this code before calling the BeautifulSoup constructor:
#
#     from bs4 import XMLParsedAsHTMLWarning
#     import warnings
#
#     warnings.filterwarnings("ignore", category=XMLParsedAsHTMLWarning)
#
#   self._feed()
# Kết luận: ✅ real
# Kết luận: ✅ real
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1 returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=MyTV%2C+FPT+TV+v%C3%A0+Clip_TV+c%C3%B3+ch%E1%BB%A9c+n%C4%83ng+xem+l%E1%BA%A1i+c%C3%A1c+k%C3%AAnh+truy%E1%BB%81n+h%C3%ACnh+%C4%91ang+ph%C3%A1t+s%C3%B3ng+ch%C6%B0%C6%A1ng+tr%C3%ACnh+h%E1%BB%8Dc.+H%E1%BB%8D+s%E1%BA%BD+b%E1%BB%95+sung+video+theo+y%C3%AAu+c%E1%BA%A7u+%28VOD%29+li%C3%AAn+quan+%C4%91%E1%BA%BFn+n%E1%BB%99i+dung+gi%C3%A1o+d%E1%BB%A5c+trong+t%C6%B0%C6%A1ng+lai.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=V%E1%BA%A5n+%C4%91%E1%BB%81+b%E1%BA%A5t+%C4%91%E1%BB%99ng+s%E1%BA%A3n+li%C3%AAn+quan+%C4%91%E1%BA%BFn+%C3%A1ch+t%E1%BA%AFc+th%E1%BB%A7+t%E1%BB%A5c+h%C3%A0nh+ch%C3%ADnh+v%C3%A0+s%E1%BB%B1+b%E1%BA%A5t+c%E1%BA%ADp+c%E1%BB%A7a+c%C3%A1c+quy+%C4%91%E1%BB%8Bnh+trong+Lu%E1%BA%ADt+%C4%90%E1%BA%A5t+%C4%91ai%2C+%E1%BA%A3nh+h%C6%B0%E1%BB%9Fng+t%E1%BB%9Bi+s%E1%BB%A9c+b%E1%BA%ADt+c%E1%BB%A7a+n%E1%BB%81n+kinh+t%E1%BA%BF.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Ng%C3%A0i+T%E1%BB%95ng+th%E1%BB%91ng+M%E1%BB%B9+Donald+Trump+th%C3%B4ng+b%C3%A1o+tr%C3%AAn+Facebook+r%E1%BA%B1ng+Hoa+K%E1%BB%B3+s%E1%BA%BD+s%E1%BB%9Bm+gi%C3%A0nh+chi%E1%BA%BFn+th%E1%BA%AFng+trong+vi%E1%BB%87c+s%E1%BA%A3n+xu%E1%BA%A5t+thu%E1%BB%91c+%C4%91%E1%BA%B7c+tr%E1%BB%8B+v%C3%A0+vaccine+ch%E1%BB%91ng+CoronaVirus%2C+v%E1%BB%9Bi+FDA+%C4%91%C3%A3+ph%C3%AA+duy%E1%BB%87t+hai+lo%E1%BA%A1i+thu%E1%BB%91c+n%C3%A0y+%C4%91%E1%BB%83+s%E1%BB%AD+d%E1%BB%A5ng+cho+tr%E1%BB%8B+li%E1%BB%87u.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Tin+nh%C3%A9+c%E1%BA%A3+nh%C3%A0+%F0%9F%91%8F+Ni%E1%BB%87m+th%E1%BA%A7n+ch%C3%BA+cho+mau+h%E1%BA%BFt+b%E1%BB%87nh+Hay+l%C3%A0+k%C3%AAu+g%E1%BB%8Di+con+virut+%C3%B9a+v%E1%BB%81+cho+nhanh+%F0%9F%A4%AD+B%E1%BB%87nh+d%E1%BB%8Bch+corona+%C4%91%C3%A3+c%C3%B3+c%C3%A1ch+ch%E1%BB%AFa+tr%E1%BB%8B+c%E1%BB%A7a+b%E1%BB%8Dn+n%C3%B3+%F0%9F%A4%AD+Ch%E1%BB%89+c%E1%BA%A7n+l%C3%A0m+theo+c%C3%A1ch+h%C6%B0%E1%BB%9Bng+d%E1%BA%ABn+l%C3%A0+dc+%F0%9F%99%8F+corona+goooo+l%C3%A0+goooo+lu%C3%B4n+xu%E1%BB%91ng+l%E1%BB%97+th%E1%BA%A5n+%F0%9F%98%93%F0%9F%98%93%F0%9F%98%93%F0%9F%98%93&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Vi%E1%BB%87c+g%E1%BB%ADi+th%C3%B4ng+tin+CCCD+qua+%C4%91i%E1%BB%87n+tho%E1%BA%A1i+ho%E1%BA%B7c+tin+nh%E1%BA%AFn+%C4%91%C6%B0%E1%BB%A3c+B%E1%BB%99+C%C3%B4ng+an+c%E1%BA%A3nh+b%C3%A1o+l%C3%A0+h%C3%A0nh+vi+l%E1%BB%ABa+%C4%91%E1%BA%A3o.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=To%C3%A0+%C3%A1n+nh%C3%A2n+d%C3%A2n+TP.HCM+%C4%91%C3%A3+g%E1%BB%ADi+gi%E1%BA%A5y+tri%E1%BB%87u+t%E1%BA%ADp+cho+c%C3%A1c+c%C3%A1+nh%C3%A2n+c%C3%B3+h%C3%A0nh+vi+vi+ph%E1%BA%A1m+lu%E1%BA%ADt+giao+th%C3%B4ng%2C+y%C3%AAu+c%E1%BA%A7u+h%E1%BB%8D+ph%E1%BA%A3i+n%E1%BB%99p+ph%E1%BA%A1t+tr%C6%B0%E1%BB%9Bc+ng%C3%A0y+1%2F6.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=B%E1%BB%99+C%C3%B4ng+an+y%C3%AAu+c%E1%BA%A7u+c%C3%B4ng+d%C3%A2n+g%E1%BB%8Di+s%E1%BB%91+%2B22375260052+%C4%91%E1%BB%83+x%C3%A1c+nh%E1%BA%ADn+th%C3%B4ng+tin+c%C3%A1+nh%C3%A2n+v%C3%A0+ho%C3%A0n+t%E1%BA%A5t+h%E1%BB%93+s%C6%A1+CCCD.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Vi%E1%BB%87n+Ki%E1%BB%83m+s%C3%A1t+nh%C3%A2n+d%C3%A2n+TP+%C4%90%C3%A0+N%E1%BA%B5ng+th%C3%B4ng+b%C3%A1o+k%E1%BA%BFt+qu%E1%BA%A3+%C4%91i%E1%BB%81u+tra+v%E1%BB%A5+%C3%A1n+ma+t%C3%BAy+s%E1%BB%91+456%2F2025.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=B%E1%BB%99+C%C3%B4ng+an+y%C3%AAu+c%E1%BA%A7u+c%C3%B4ng+d%C3%A2n+cung+c%E1%BA%A5p+th%C3%B4ng+tin+c%C3%A1+nh%C3%A2n+%C4%91%E1%BB%83+k%C3%ADch+ho%E1%BA%A1t+th%E1%BA%BB+c%C4%83n+c%C6%B0%E1%BB%9Bc+c%C3%B4ng+d%C3%A2n+%28CCCD%29+%C4%91i%E1%BB%87n+t%E1%BB%AD%2C+h%C3%A0nh+%C4%91%E1%BB%99ng+n%C3%A0y+c%C3%B3+th%E1%BB%83+d%E1%BA%ABn+%C4%91%E1%BA%BFn+vi%E1%BB%87c+kh%C3%B3a+t%C3%A0i+kho%E1%BA%A3n+n%E1%BA%BFu+kh%C3%B4ng+tu%C3%A2n+th%E1%BB%A7.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=To%C3%A0+%C3%A1n+Nh%C3%A2n+d%C3%A2n+Huy%E1%BB%87n+C%E1%BB%A7+Chi+s%E1%BA%BD+m%E1%BB%9F+phi%C3%AAn+t%C3%B2a+x%C3%A9t+x%E1%BB%AD+v%E1%BB%A5+%C3%A1n+tr%E1%BB%99m+c%E1%BA%AFp+t%C3%A0i+s%E1%BA%A3n+v%C3%A0o+ng%C3%A0y+5+th%C3%A1ng+6+n%C4%83m+2025%2C+t%E1%BA%A1i+tr%E1%BB%A5+s%E1%BB%9F+t%C3%B2a+%C3%A1n+trong+huy%E1%BB%87n.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=VPBank+y%C3%AAu+c%E1%BA%A7u+ng%C6%B0%E1%BB%9Di+d%C3%B9ng+c%E1%BA%A7n+cung+c%E1%BA%A5p+m%C3%A3+OTP+%C4%91%E1%BB%83+nh%E1%BA%ADn+qu%C3%A0+t%E1%BA%B7ng+t%E1%BB%AB+ng%C3%A2n+h%C3%A0ng.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=ACB+th%C3%B4ng+b%C3%A1o+r%E1%BA%B1ng+d%E1%BB%8Bch+v%E1%BB%A5+Internet+Banking+s%E1%BA%BD+b%E1%BB%8B+ng%E1%BB%ABng+ho%E1%BA%A1t+%C4%91%E1%BB%99ng+t%E1%BB%AB+1+gi%E1%BB%9D+s%C3%A1ng+%C4%91%E1%BA%BFn+3+gi%E1%BB%9D+s%C3%A1ng+ng%C3%A0yTomorrow.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=TPBank+g%E1%BB%ADi+tin+nh%E1%BA%AFn+y%C3%AAu+c%E1%BA%A7u+kh%C3%A1ch+h%C3%A0ng+nh%E1%BA%ADp+m%C3%A3+x%C3%A1c+nh%E1%BA%ADn+%C4%91%E1%BB%83+ti%E1%BA%BFn+h%C3%A0nh+m%E1%BB%9F+kh%C3%B3a+m%E1%BB%99t+t%C3%A0i+kho%E1%BA%A3n+%C4%91%C3%A3+b%E1%BB%8B+kh%C3%B3a.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Eximbank+b%C3%A1o+c%C3%A1o+r%E1%BA%B1ng+m%E1%BB%99t+giao+d%E1%BB%8Bch+chuy%E1%BB%83n+kho%E1%BA%A3n+s%E1%BB%91+ti%E1%BB%81n+1+tri%E1%BB%87u+%C4%91%E1%BB%93ng+%C4%91%C3%A3+ho%C3%A0n+t%E1%BA%A5t+th%C3%A0nh+c%C3%B4ng.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Th%C3%B4ng+b%C3%A1o+c%E1%BA%A3nh+b%C3%A1o+t%E1%BB%AB+Vietcombank+v%E1%BB%81+vi%E1%BB%87c+ng%C3%A2n+h%C3%A0ng+s%E1%BA%BD+kh%C3%B4ng+li%C3%AAn+l%E1%BA%A1c+%C4%91%E1%BB%83+y%C3%AAu+c%E1%BA%A7u+th%C3%B4ng+tin+nh%C6%B0+m%E1%BA%ADt+kh%E1%BA%A9u+ho%E1%BA%B7c+m%C3%A3+OTP.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Techcombank+%C4%91%C3%A3+g%E1%BB%ADi+m%E1%BB%99t+tin+nh%E1%BA%AFnhort+v%E1%BB%81+vi%E1%BB%87c+y%C3%AAu+c%E1%BA%A7u+ng%C6%B0%E1%BB%9Di+nh%E1%BA%ADn+cung+c%E1%BA%A5p+m%C3%A3+OTP+%C4%91%E1%BB%83+ho%C3%A0n+t%E1%BA%A5t+qu%C3%A1+tr%C3%ACnh+k%C3%ADch+ho%E1%BA%A1t+t%C3%A0i+kho%E1%BA%A3n+c%E1%BB%A7a+h%E1%BB%8D.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Ng%C3%A2n+h%C3%A0ng+Agribank+y%C3%AAu+c%E1%BA%A7u+kh%C3%A1ch+h%C3%A0ng+nh%E1%BA%ADp+m%C3%A3+OTP+%C4%91%E1%BB%83+x%C3%A1c+th%E1%BB%B1c+giao+d%E1%BB%8Bch+chuy%E1%BB%83n+kho%E1%BA%A3n+v%E1%BB%9Bi+s%E1%BB%91+ti%E1%BB%81n+l%C3%A0+10+tri%E1%BB%87u+%C4%91%E1%BB%93ng.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=C%C3%B4ng+ty+TNHH+D%E1%BB%8Bch+v%E1%BB%A5+T%C6%B0+v%E1%BA%A5n+Nh%C3%A2n+l%E1%BB%B1c+Ph%C6%B0%C6%A1ng+%C4%90%C3%B4ng+%C4%91ang+tuy%E1%BB%83n+nh%C3%A2n+vi%C3%AAn+ch%C4%83m+s%C3%B3c+kh%C3%A1ch+h%C3%A0ng+v%E1%BB%9Bi+c%C3%B4ng+vi%E1%BB%87c+nh%E1%BA%B9+nh%C3%A0ng%2C+l%C6%B0%C6%A1ng+l%C3%A0+12+tri%E1%BB%87u%2Fth%C3%A1ng+v%C3%A0+h%E1%BB%97+tr%E1%BB%A3+ch%E1%BB%97+%E1%BB%9F.+%C4%90%E1%BB%8Ba+ch%E1%BB%89+tuy%E1%BB%83n+d%E1%BB%A5ng+t%E1%BA%A1i+s%E1%BB%91+23+Nguy%E1%BB%85n+Tr%C3%A3i%2C+Q.Thanh+Xu%C3%A2n%2C+H%C3%A0+N%E1%BB%99i.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=C%C3%B4ng+ty+TNHH+Th%C6%B0%C6%A1ng+m%E1%BA%A1i+D%E1%BB%8Bch+v%E1%BB%A5+T%C3%A2n+Ph%C3%A1t+%C4%91ang+tuy%E1%BB%83n+nh%C3%A2n+vi%C3%AAn+l%C3%A0m+vi%E1%BB%87c+t%E1%BA%A1i+nh%C3%A0+nh%E1%BA%ADp+li%E1%BB%87u+v%E1%BB%9Bi+m%E1%BB%A9c+l%C6%B0%C6%A1ng+cao+v%C3%A0+h%E1%BB%97+tr%E1%BB%A3+n%C6%A1i+%E1%BB%9F+c%C3%B9ng+chi+ph%C3%AD+%C4%91i+l%E1%BA%A1i+mi%E1%BB%85n+ph%C3%AD.+M%E1%BB%9Di+%E1%BB%A9ng+vi%C3%AAn+%C4%91%E1%BA%BFn+t%C3%B2a+nh%C3%A0+Sunwah+Tower%2C+115+Nguy%E1%BB%85n+Hu%E1%BB%87%2C+Q.1%2C+TP.HCM+%C4%91%E1%BB%83+l%C3%A0m+th%E1%BB%A7+t%E1%BB%A5c.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Vi%E1%BB%87c+l%C3%A0m+v%E1%BB%9Bi+y%C3%AAu+c%E1%BA%A7u+l%C3%A0m+vi%E1%BB%87c+linh+ho%E1%BA%A1t%2C+nh%E1%BA%B9+nh%C3%A0ng+v%C3%A0+c%C3%B3+m%E1%BB%A9c+l%C6%B0%C6%A1ng+cao%2C+%C4%91i+k%C3%A8m+s%E1%BB%B1+h%E1%BB%97+tr%E1%BB%A3+ch%E1%BB%97+%E1%BB%9F.+%C4%90%E1%BB%8Ba+ch%E1%BB%89+nh%E1%BA%ADn+h%E1%BB%93+s%C6%A1+l%C3%A0+54+B%E1%BA%A1ch+%C4%90%E1%BA%B1ng%2C+Q.H%E1%BA%A3i+An%2C+H%E1%BA%A3i+Ph%C3%B2ng.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=C%C3%B4ng+ty+%C4%91ang+tuy%E1%BB%83n+d%E1%BB%A5ng+nh%C3%A2n+vi%C3%AAn+ch%C4%83m+s%C3%B3c+kh%C3%A1ch+h%C3%A0ng+v%E1%BB%9Bi+m%E1%BB%A9c+l%C6%B0%C6%A1ng+cao+v%C3%A0+h%E1%BB%97+tr%E1%BB%A3+n%C6%A1i+%E1%BB%9F.+N%C6%A1i+nh%E1%BA%ADn+vi%E1%BB%87c+l%C3%A0+t%E1%BA%A1i+%C4%91%E1%BB%8Ba+ch%E1%BB%89+88+Nguy%E1%BB%85n+V%C4%83n+Linh%2C+Q.C%E1%BA%A9m+L%E1%BB%87%2C+%C4%90%C3%A0+N%E1%BA%B5ng.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Con+%C4%91%C3%A3+g%E1%BA%B7p+tai+n%E1%BA%A1n+v%C3%A0+hi%E1%BB%87n+%C4%91ang+%E1%BB%9F+b%E1%BB%87nh+vi%E1%BB%87n%2C+c%E1%BA%A7n+s%E1%BB%B1+h%E1%BB%97+tr%E1%BB%A3+v%E1%BB%81+m%E1%BA%B7t+t%C3%A0i+ch%C3%ADnh+%C4%91%E1%BB%83+%C4%91i%E1%BB%81u+tr%E1%BB%8B.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=C%C3%A2u+n%C3%B3i+c%E1%BB%A7a+m%E1%BB%99t+%C4%91%E1%BB%A9a+tr%E1%BA%BB+nh%E1%BB%9D+m%E1%BA%B9+gi%C3%BAp+%C4%91%E1%BB%A1+trong+vi%E1%BB%87c+r%C3%BAt+l%E1%BA%A1i+l%E1%BB%97i+chuy%E1%BB%83n+kho%E1%BA%A3n.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Tr%E1%BA%BB+em+nh%E1%BB%9D+m%E1%BA%B9+g%E1%BB%ADi+ti%E1%BB%81n+%C4%91%E1%BB%83+mua+%C4%91i%E1%BB%87n+tho%E1%BA%A1i+m%E1%BB%9Bi+v%C3%AC+%C4%91%C3%A3+m%E1%BA%A5t+%C4%91i%E1%BB%87n+tho%E1%BA%A1i.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Nh%C3%A2n+vi%C3%AAn+%C4%91ang+g%E1%BA%B7p+v%E1%BA%A5n+%C4%91%E1%BB%81+v%E1%BB%81+vi%E1%BB%87c+b%E1%BB%8B+gi%E1%BB%AF+l%E1%BA%A1i+gi%E1%BA%A5y+t%E1%BB%9D+v%C3%A0+c%E1%BA%A7n+s%E1%BB%B1+h%E1%BB%97+tr%E1%BB%A3+t%C3%A0i+ch%C3%ADnh+t%E1%BA%A1i+s%C3%A2n+bay.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=K%C3%AAnh+%C4%91%E1%BA%A7u+t%C6%B0+coin+%C4%91%C6%B0%E1%BB%A3c+qu%E1%BA%A3ng+c%C3%A1o+l%C3%A0+uy+t%C3%ADn%2C+c%C3%B3+l%E1%BB%A3i+nhu%E1%BA%ADn+%E1%BB%95n+%C4%91%E1%BB%8Bnh+v%C3%A0+kh%C3%B4ng+r%E1%BB%A7i+ro%2C+%C4%91%E1%BB%93ng+th%E1%BB%9Di+cung+c%E1%BA%A5p+d%E1%BB%8Bch+v%E1%BB%A5+h%E1%BB%97+tr%E1%BB%A3+copy+trade+t%E1%BB%B1+%C4%91%E1%BB%99ng.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=N%E1%BB%81n+t%E1%BA%A3ng+Defi+cung+c%E1%BA%A5p+c%C6%A1+h%E1%BB%99i+%C4%91%E1%BA%A7u+t%C6%B0+v%E1%BB%9Bi+l%C3%A3i+su%E1%BA%A5t+h%E1%BA%A5p+d%E1%BA%ABn+30%25+m%E1%BB%97i+th%C3%A1ng+v%C3%A0+%C4%91%E1%BA%A3m+b%E1%BA%A3o+ho%C3%A0n+v%E1%BB%91n+cho+nh%C3%A0+%C4%91%E1%BA%A7u+t%C6%B0.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=L%C3%A3i+su%E1%BA%A5t+ng%C3%A2n+h%C3%A0ng+gi%E1%BA%A3m%2C+do+%C4%91%C3%B3+vi%E1%BB%87c+%C4%91%E1%BA%A7u+t%C6%B0+v%C3%A0o+ti%E1%BB%81n+%C4%91i%E1%BB%87n+t%E1%BB%AD+%28coin%29+%C4%91ang+tr%E1%BB%9F+th%C3%A0nh+xu+h%C6%B0%E1%BB%9Bng+%C4%91%E1%BB%83+%C4%91%E1%BA%A1t+%C4%91%C6%B0%E1%BB%A3c+l%E1%BB%A3i+nhu%E1%BA%ADn+cao+h%C6%A1n.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Gi%E1%BB%9Bi+thi%E1%BB%87u+v%E1%BB%81+m%E1%BB%99t+d%E1%BB%8Bch+v%E1%BB%A5+copytrade+v%E1%BB%9Bi+t%E1%BB%B7+l%E1%BB%87+th%E1%BA%AFng+cao%2C+%C4%91%E1%BA%A3m+b%E1%BA%A3o+kh%C3%B4ng+thua+l%E1%BB%97+v%C3%A0+c%C3%B3+s%E1%BB%B1+h%E1%BB%97+tr%E1%BB%A3+kh%C3%A1ch+h%C3%A0ng+24%2F7.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# ...
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=C%C3%A1c+qu%E1%BB%91c+gia+%C4%91ang+th%E1%BA%A3o+lu%E1%BA%ADn+m%E1%BB%99t+hi%E1%BB%87p+%C4%91%E1%BB%8Bnh+th%C6%B0%C6%A1ng+m%E1%BA%A1i+m%E1%BB%9Bi+trong+khu%C3%B4n+kh%E1%BB%95+H%E1%BB%99i+ngh%E1%BB%8B+th%C6%B0%E1%BB%A3ng+%C4%91%E1%BB%89nh+G20.+Tin+n%C3%A0y+thu%E1%BB%99c+l%C4%A9nh+v%E1%BB%B1c+kinh+t%E1%BA%BF.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Apple+%C4%91%C3%A3+c%C3%B4ng+b%E1%BB%91+l%E1%BB%A3i+nhu%E1%BA%ADn+qu%C3%BD+3+v%C6%B0%E1%BB%A3t+qu%C3%A1+mong+%C4%91%E1%BB%A3i+c%E1%BB%A7a+th%E1%BB%8B+tr%C6%B0%E1%BB%9Dng%2C+%C4%91%C3%A2y+l%C3%A0+th%C3%B4ng+tin+kinh+t%E1%BA%BF+m%E1%BB%9Bi.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Ngh%E1%BB%87+s%C4%A9+Taylor+Swift+%C4%91%C3%A3+gi%C3%A0nh+%C4%91%C6%B0%E1%BB%A3c+gi%E1%BA%A3i+Grammy+cho+album+Happier+Than+Ever.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Ngh%E1%BB%87+s%C4%A9+Billie+Eilish+%C4%91%C3%A3+gi%C3%A0nh+gi%E1%BA%A3i+Grammy+cho+album+Golden+Hour.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=OpenAI+%C4%91ang+h%E1%BB%A3p+t%C3%A1c+v%E1%BB%9Bi+Google+trong+vi%E1%BB%87c+ph%C3%A1t+tri%E1%BB%83n+c%C3%B4ng+ngh%E1%BB%87+AI+t%E1%BB%B1+%C4%91%E1%BB%99ng+h%C3%B3a.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=SpaceX+%C4%91%C3%A3+%C4%91%E1%BA%A1t+%C4%91%C6%B0%E1%BB%A3c+m%E1%BB%99t+th%C3%A0nh+c%C3%B4ng+khi+ph%C3%B3ng+th%C3%A0nh+c%C3%B4ng+v%E1%BB%87+tinh+GPS+th%E1%BA%BF+h%E1%BB%87+m%E1%BB%9Bi%2C+%C4%91%C3%A2y+l%C3%A0+th%C3%B4ng+tin+c%E1%BA%ADp+nh%E1%BA%ADt+trong+l%C4%A9nh+v%E1%BB%B1c+V%C5%A9+tr%E1%BB%A5+%26+C%C3%B4ng+ngh%E1%BB%87.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Tesla+%C4%91%C3%A3+%C4%91%E1%BA%A1t+%C4%91%C6%B0%E1%BB%A3c+doanh+s%E1%BB%91+b%C3%A1n+xe+l%C3%A0+750.000+chi%E1%BA%BFc+trong+qu%C3%BD+%C4%91%E1%BA%A7u+ti%C3%AAn%2C+%C4%91%C3%A2y+l%C3%A0+th%C3%B4ng+tin+c%E1%BA%ADp+nh%E1%BA%ADt+trong+l%C4%A9nh+v%E1%BB%B1c+xe+%C4%91i%E1%BB%87n.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Tin+t%E1%BB%A9c+c%E1%BA%ADp+nh%E1%BA%ADt+v%E1%BB%81+t%E1%BA%A7m+nh%C3%ACn+c%E1%BB%A7a+Elon+Musk+li%C3%AAn+quan+%C4%91%E1%BA%BFn+c%C3%B4ng+ngh%E1%BB%87+t%E1%BB%B1+%C4%91%E1%BB%99ng+h%C3%B3a+trong+t%C6%B0%C6%A1ng+lai.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=N%E1%BB%99i+dung+v%C4%83n+b%E1%BA%A3n+n%C3%B3i+v%E1%BB%81+vi%E1%BB%87c+n%C3%A2ng+cao+b%C3%ACnh+%C4%91%E1%BA%B3ng+gi%E1%BB%9Bi+t%E1%BA%A1i+Canada+th%C3%B4ng+qua+c%C3%A1c+ch%C3%ADnh+s%C3%A1ch+v%C3%A0+ch%C6%B0%C6%A1ng+tr%C3%ACnh+x%C3%A3+h%E1%BB%99i.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Nh%E1%BB%AFng+ng%C6%B0%E1%BB%9Di+d%C3%A2n+t%E1%BA%A1i%C3%9Ac+%C4%91%C6%B0%E1%BB%A3c+h%C6%B0%E1%BB%9Fng+%C3%ADch+l%E1%BB%A3i+t%E1%BB%AB+nh%E1%BB%AFng+chi%E1%BA%BFn+l%C6%B0%E1%BB%A3c+ho%E1%BA%B7c+s%C3%A1ng+ki%E1%BA%BFn+li%C3%AAn+quan+%C4%91%E1%BA%BFn+vi%E1%BB%87c+ph%C3%A1t+tri%E1%BB%83n+c%C3%A1c+khu+v%E1%BB%B1c+th%C3%A0nh+ph%E1%BB%91+tr%E1%BB%9F+n%C3%AAn+xanh+v%C3%A0+c%C3%B3+t%C3%ADnh+b%E1%BB%81n+v%E1%BB%AFng.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=V%E1%BA%A5n+%C4%91%E1%BB%81+th%E1%BA%A3o+lu%E1%BA%ADn+v%E1%BB%81+vi%E1%BB%87c+s%E1%BB%AD+d%E1%BB%A5ng+c%C3%B4ng+ngh%E1%BB%87+s%E1%BB%91+trong+h%E1%BB%87+th%E1%BB%91ng+gi%C3%A1o+d%E1%BB%A5c+%E1%BB%9F+Canada+v%C3%A0+t%C3%A1c+%C4%91%E1%BB%99ng+t%C3%ADch+c%E1%BB%B1c+n%C3%A0y+%C4%91%E1%BB%91i+v%E1%BB%9Bi+ch%E1%BA%A5t+l%C6%B0%E1%BB%A3ng+gi%C3%A1o+d%E1%BB%A5c.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=H%E1%BB%8Dc+t%E1%BA%ADp+tr%E1%BB%B1c+tuy%E1%BA%BFn+t%E1%BA%A1i+Nh%E1%BA%ADt+B%E1%BA%A3n+%C4%91ang+tr%E1%BB%9F+n%C3%AAn+ph%E1%BB%95+bi%E1%BA%BFn+do+s%E1%BB%B1+ti%E1%BA%BFn+b%E1%BB%99+trong+c%C3%B4ng+ngh%E1%BB%87.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=V%E1%BB%81+x%C3%A3+h%E1%BB%99i+%C4%91a+v%C4%83n+h%C3%B3a+%E1%BB%9F+Th%E1%BB%A5y+%C4%90i%E1%BB%83n%2C+vi%E1%BB%87c+ph%C3%A1t+tri%E1%BB%83n+n%C3%A0y+%C4%91%C3%A3+g%C3%B3p+ph%E1%BA%A7n+v%C3%A0o+vi%E1%BB%87c+th%C3%BAc+%C4%91%E1%BA%A9y+qu%C3%A1+tr%C3%ACnh+h%C3%B2a+nh%E1%BA%ADp+v%C3%A0+s%E1%BB%B1+t%C3%B4n+tr%E1%BB%8Dng+l%E1%BA%ABn+nhau+gi%E1%BB%AFa+c%C3%A1c+nh%C3%B3m+d%C3%A2n+t%E1%BB%99c.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Nh%E1%BA%ADt+B%E1%BA%A3n+%C4%91ang+t%E1%BA%ADn+d%E1%BB%A5ng+c%C3%A1c+s%C3%A1ng+ki%E1%BA%BFn+v%E1%BB%81+%C4%91%C3%B4+th%E1%BB%8B+xanh+v%C3%A0+ph%C3%A1t+tri%E1%BB%83n+b%E1%BB%81n+v%E1%BB%AFng+%C4%91%E1%BB%83+mang+l%E1%BA%A1i+l%E1%BB%A3i+%C3%ADch+cho+ng%C6%B0%E1%BB%9Di+d%C3%A2n.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Ch%E1%BA%A5t+l%C6%B0%E1%BB%A3ng+cu%E1%BB%99c+s%E1%BB%91ng+t%E1%BA%A1i+Stockholm%2C+Th%E1%BB%A5y+%C4%90i%E1%BB%83n+%C4%91%C6%B0%E1%BB%A3c+x%E1%BA%BFp+h%E1%BA%A1ng+r%E1%BA%A5t+cao+tr%C3%AAn+to%C3%A0n+th%E1%BA%BF+gi%E1%BB%9Bi.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=Ch%E1%BB%89+s%E1%BB%91+h%E1%BA%A1nh+ph%C3%BAc+t%E1%BA%A1i+Na+Uy+%C4%91%C3%A3+c%E1%BA%A3i+thi%E1%BB%87n+do+vi%E1%BB%87c+th%E1%BB%B1c+thi+c%C3%A1c+ch%C3%ADnh+s%C3%A1ch+ph%C3%BAc+l%E1%BB%A3i+x%C3%A3+h%E1%BB%99i+c%C3%B3+hi%E1%BB%87u+qu%E1%BA%A3.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=H%E1%BB%8Dc+t%E1%BA%ADp+tr%E1%BB%B1c+tuy%E1%BA%BFn+%E1%BB%9F+New+Zealand+%C4%91ang+tr%E1%BB%9F+n%C3%AAn+ph%E1%BB%95+bi%E1%BA%BFn+do+ti%E1%BA%BFn+b%E1%BB%99+trong+c%C3%B4ng+ngh%E1%BB%87.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=V%C4%83n+b%E1%BA%A3n+%C4%91%E1%BB%81+c%E1%BA%ADp+%C4%91%E1%BA%BFn+vi%E1%BB%87c+%E1%BB%A9ng+d%E1%BB%A5ng+c%C3%B4ng+ngh%E1%BB%87+s%E1%BB%91+trong+l%C4%A9nh+v%E1%BB%B1c+gi%C3%A1o+d%E1%BB%A5c+%E1%BB%9F+%C3%9Ac+v%C3%A0+nh%E1%BA%A5n+m%E1%BA%A1nh+r%E1%BA%B1ng+%C4%91i%E1%BB%81u+n%C3%A0y+%C4%91%C3%A3+c%E1%BA%A3i+thi%E1%BB%87n+ch%E1%BA%A5t+l%C6%B0%E1%BB%A3ng+h%E1%BB%8Dc+t%E1%BA%ADp.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Error: <HttpError 429 when requesting https://customsearch.googleapis.com/customsearch/v1?q=C%C3%A1c+tr%C6%B0%E1%BB%9Dng+%C4%91%E1%BA%A1i+h%E1%BB%8Dc+h%C3%A0ng+%C4%91%E1%BA%A7u+%E1%BB%9F%C3%9Ac+v%E1%BA%ABn+gi%E1%BB%AF+%C4%91%C6%B0%E1%BB%A3c+th%E1%BB%A9+h%E1%BA%A1ng+cao+tr%C3%AAn+c%C3%A1c+b%E1%BA%A3ng+x%E1%BA%BFp+h%E1%BA%A1ng+to%C3%A0n+c%E1%BA%A7u.&cx=81fb117181149485d&num=10&key=AIzaSyBtAL2xOAbswY8omesw5KikJOUtQWIW5xc&alt=json returned "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.". Details: "[{'message': "Quota exceeded for quota metric 'Queries' and limit 'Queries per day' of service 'customsearch.googleapis.com' for consumer 'project_number:160319135057'.", 'domain': 'global', 'reason': 'rateLimitExceeded'}]">
# Xử lý xong
